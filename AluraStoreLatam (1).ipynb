# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plot

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### Calculo de ingresos totales por tienda

# %%
ingresos_tienda1 = tienda['Precio'].sum()
ingresos_tienda2 = tienda2['Precio'].sum()
ingresos_tienda3 = tienda3['Precio'].sum()
ingresos_tienda4 = tienda4['Precio'].sum()
print(f'Ingresos totales tienda 1: {ingresos_tienda1} ')
print(f'Ingresos totales tienda 2: {ingresos_tienda2} ')
print(f'Ingresos totales tienda 3: {ingresos_tienda3} ')
print(f'Ingresos totales tienda 4: {ingresos_tienda4} ')
# Out:
# Ingresos totales tienda 1: 1150880400.0
# Ingresos totales tienda 2: 1116343500.0
# Ingresos totales tienda 3: 1098019600.0
# Ingresos totales tienda 4: 1038375700.0

# %%
ingresos = pd.Series(
    [ingresos_tienda1, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

ax = ingresos.plot(kind="bar")
ax.set_ylabel("Ingresos totales")
ax.set_title("Ingresos totales por tienda")
plot.show()

# %% [markdown]
# ### Ventas por categoria

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ### Ventas por categoria y tienda
# Se clasifica por Categoria del producto, usando .size para contar la cantidad por categoria, reset index para dar nombre a la columna y sortvalues para ordenar de forma descendente.

# %% [markdown]
# ### TIENDA 1

# %%
porcategoria_tienda1 =tienda.groupby("Categoría del Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porcategoria_tienda1.head()
# Out:
#   Categoría del Producto  ventas
# 7                Muebles     465
# 3           Electrónicos     448
# 5               Juguetes     324
# 2      Electrodomésticos     312
# 1   Deportes y diversión     284

# %%
porcategoria_tienda1.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ### TIENDA 2

# %%
porcategoria_tienda2 =tienda2.groupby("Categoría del Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porcategoria_tienda2.head()
# Out:
#   Categoría del Producto  ventas
# 7                Muebles     442
# 3           Electrónicos     422
# 5               Juguetes     313
# 2      Electrodomésticos     305
# 1   Deportes y diversión     275

# %%
porcategoria_tienda2.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ### TIENDA 3

# %%
porcategoria_tienda3 =tienda3.groupby("Categoría del Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porcategoria_tienda3.head()
# Out:
#   Categoría del Producto  ventas
# 7                Muebles     499
# 3           Electrónicos     451
# 5               Juguetes     315
# 2      Electrodomésticos     278
# 1   Deportes y diversión     277

# %%
porcategoria_tienda3.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ### TIENDA 4

# %%
porcategoria_tienda4 = tienda4.groupby("Categoría del Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porcategoria_tienda4.head()
# Out:
#   Categoría del Producto  ventas
# 7                Muebles     480
# 3           Electrónicos     451
# 5               Juguetes     338
# 1   Deportes y diversión     277
# 2      Electrodomésticos     254

# %%
porcategoria_tienda4.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# # 3. Calificación promedio de la tienda
# Debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.
#
# Esto, con ayuda de .mean() que muestra el promedio de esa columa "Calificacion".
# round(2), para que el valor tenga 2 decimales.

# %%
calif_promedio1 = tienda['Calificación'].mean().round(2)
calif_promedio2 = tienda2['Calificación'].mean().round(2)
calif_promedio3 = tienda3['Calificación'].mean().round(2)
calif_promedio4 = tienda4['Calificación'].mean().round(2)
print(f'Promedio tienda 1: {calif_promedio1}')
print(f'Promedio tienda 2: {calif_promedio2}')
print(f'Promedio tienda 3: {calif_promedio3}')
print(f'Promedio tienda 4: {calif_promedio4}')
# Out:
# Promedio tienda 1: 3.98
# Promedio tienda 2: 4.04
# Promedio tienda 3: 4.05
# Promedio tienda 4: 4.0

# %%
promedios1 = pd.Series(
    [calif_promedio1, calif_promedio2, calif_promedio3, calif_promedio4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

promedios1.plot(kind="barh", ylabel="Promedio de calificación", title="Comparación de promedio por tienda")
plot.ylim(0,5)  # rango estándar de calificaciones
plot.show()

# %% [markdown]
# # 4. Productos más y menos vendidos
# Lo hacemos de la misma forma que las categorias mas vendidas, solo que ahora con la columna producto.
# Size para la cantidad en esa fila - .reset_index(name=ventas) para la columna resultante. Sortvalues para organizar.

# %% [markdown]
# ### TIENDA 1

# %%
porproducto_tienda1 = tienda.groupby("Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porproducto_tienda1.head()
# Out:
#             Producto  ventas
# 1            Armario      60
# 48     TV LED UHD 4K      60
# 33        Microondas      60
# 40  Secadora de ropa      58
# 32     Mesa de noche      56

# %%
porproducto_tienda1.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# ### TIENDA 2

# %%
porproducto_tienda2 = tienda2.groupby("Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porproducto_tienda2.head()
# Out:
#                      Producto  ventas
# 24  Iniciando en programación      65
# 33                 Microondas      62
# 7                     Batería      61
# 38                  Pandereta      58
# 21          Guitarra acústica      58

# %%
porproducto_tienda2.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# TIENDA 3

# %%
porproducto_tienda3 = tienda3.groupby("Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porproducto_tienda3.head()
# Out:
#            Producto  ventas
# 27    Kit de bancas      57
# 31  Mesa de comedor      56
# 11        Cama king      56
# 41     Set de ollas      55
# 32    Mesa de noche      55

# %%
porproducto_tienda3.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# ### TIENDA 4

# %%
porproducto_tienda4 = tienda4.groupby("Producto").size().reset_index(name="ventas").sort_values(by="ventas", ascending=False)
porproducto_tienda4.head()
# Out:
#                      Producto  ventas
# 10                   Cama box      62
# 15                 Cubertería      59
# 11                  Cama king      56
# 18    Dashboards con Power BI      56
# 12  Carrito de control remoto      55

# %%
porproducto_tienda4.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_prom_tienda1 = tienda['Costo de envío'].mean()
envio_prom_tienda1.round(2)
envio_prom_tienda2 = tienda2['Costo de envío'].mean()
envio_prom_tienda2.round(2)
envio_prom_tienda3 = tienda3['Costo de envío'].mean()
envio_prom_tienda3.round(2)
envio_prom_tienda4 = tienda4['Costo de envío'].mean()
envio_prom_tienda4.round(2)
# Out:
# np.float64(23459.46)

# %%
promedios2 = pd.Series(
    [envio_prom_tienda1, envio_prom_tienda2, envio_prom_tienda3, envio_prom_tienda4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

promedios2.plot(kind="barh", ylabel="Promedio de envio por tienda", title="Comparación de promedio envio por tienda")
plot.ylim(0,5)  # rango estándar de calificaciones
plot.show()

# %% [markdown]
# #ANALISIS FINAL
#
# 1. Los ingresos totales de las tiendas lo vemos reflejado en el siguiente grafico:
# Ingresos totales tienda 1: 1150880400.0 <br>
# Ingresos totales tienda 2: 1116343500.0 <br>
# Ingresos totales tienda 3: 1098019600.0<br>
# Ingresos totales tienda 4: 1038375700.0

# %%
ingresos = pd.Series(
    [ingresos_tienda1, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

ax = ingresos.plot(kind="bar")
ax.set_ylabel("Ingresos totales")
ax.set_title("Ingresos totales por tienda")
plot.show()

# %% [markdown]
# Reflejando de esta forma que la tienda con menos ingresos es la tienda numero 4.

# %% [markdown]
# # 2. Categorias de productos mas y menos vendidos

# %% [markdown]
# ## TIENDA 1

# %%
porcategoria_tienda1.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ## TIENDA 2

# %%
porcategoria_tienda2.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ## TIENDA 3

# %%
porcategoria_tienda3.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# ## TIENDA 4

# %%
porcategoria_tienda4.head().plot(kind="pie", x="Categoría del Producto", y="ventas")
# Out:
# <Axes: ylabel='ventas'>

# %% [markdown]
# # 3. Calificacion promedio de los clientes

# %%
promedios1 = pd.Series(
    [calif_promedio1, calif_promedio2, calif_promedio3, calif_promedio4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

promedios1.plot(kind="barh", ylabel="Promedio de calificación", title="Comparación de promedio por tienda")
plot.ylim(0,5)  # rango estándar de calificaciones
plot.show()

# %% [markdown]
# La tienda con menor promedio de calificacion es la tienda numero 1

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ### TIENDA 1

# %%
porproducto_tienda1.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# Los productos con mayor venta son: <br>-Armario <br>
# -TVLED <br>
# -Microondas <br>
# -Secadora ropa <br>
# -Mesa de noche <br>

# %% [markdown]
# ### TIENDA 2

# %%
porproducto_tienda2.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# Los productos con mayor venta son: <br>-Iniciando en programacion <br>
# -Microondas <br>
# -Bateria <br>
# -Pandereta <br>
# -Guitarra acustica <br>

# %% [markdown]
# ### TIENDA 3

# %%
porproducto_tienda3.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# Los productos con mayor venta son: <br>-Kit de bancas <br>
# -Mesa de comedor <br>
# -Cama king <br>
# -Set de ollas <br>
# -Mesa de noche <br>

# %% [markdown]
# ### TIENDA 4

# %%
porproducto_tienda4.head().plot(kind="scatter", x="Producto", y="ventas")
# Out:
# <Axes: xlabel='Producto', ylabel='ventas'>

# %% [markdown]
# Los productos con mayor venta son: <br>-Cama box <br>
# -Cuberteria <br>
# -Cama king <br>
# -Dashboards <br>
# -Control remoto <br>

# %% [markdown]
# # 5. Coste de envio promedio

# %%
promedios2 = pd.Series(
    [envio_prom_tienda1, envio_prom_tienda2, envio_prom_tienda3, envio_prom_tienda4],
    index=["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
)

promedios2.plot(kind="barh", ylabel="Promedio de envio por tienda", title="Comparación de promedio envio por tienda")
plot.ylim(0,5)  # rango estándar de calificaciones
plot.show()

# %% [markdown]
# La tienda con mayor coste de envio es la tienda numero 1

# %% [markdown]
# # ARGUMENTOS:
# ## TIENDA 1:
# La tienda 1 tiene el promedio de envio mas alto, siendo Armario y TVLED los productos mas vendidos, así mismo su calificacion es la menor de todas y la categoria con mayores productos vendidos es: Muebles y la de menor: Articulos para el hogar
#
# ## TIENDA 2:
# La tienda numero 2 tiene el segundo valor de ingresos mas alto, con su categoria de ventas mas alta en muebles y la menor en Articulos para el hogar, tiene el segundo promedio en calificacion y sus produtos mas vendidos como Microondas, su coste promedio de envio es el segundo en la lista.
#
# ## TIENDA 3:
# La tienda numero 3 tiene el 3er promedio en coste de envio, sus productos mas vendidos son los kits de banas, mesa comedor y camaking. Su calificacion por parte de los clientes es la mas alta y su categoria mas vendida son muebles y las menores con empate entre Articulos para el hogar y instrumentos musicales y es la 3ra tiena en el orden de ingresos.
#
# ## TIENDA 4:
# Es la tienda con menores ingresos, con sus mayores ventas en muebles, y la menor son instrumentos musicales, su caificacion es la segunda mas baja y tiene grandes cantidades en ventas de cama box y cuberteria y es la menor en en coste de envios.

# %% [markdown]
# # DECISION FINAL:
# La tienda 4 presenta el menor nivel de ingresos, desempeño de ventas inferior y calificación promedio baja. A pesar de tener el menor costo de envío, este valor lo asume el cliente, por lo que no impacta positivamente la rentabilidad. Se recomienda que la tienda cerrada sea la NUMERO 4
